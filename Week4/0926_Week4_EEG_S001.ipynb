# %% [markdown]
# 1차원 데이터를 가공하여 2차원 데이터로 변환하기

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
eeg_width = 512
eeg_data = []

# %%
eeg_data = np.loadtxt('C:/Project/MachineLearning/Data/S001.csv', delimiter=',', dtype=np.float32)

np_eeg_data = np.array(eeg_data)

plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams['figure.figsize'] = 6, 6
x = []
s = 1
for i in range(int(len(eeg_data))):
    x.append(s)
    s = s + 1
plt.plot(x, eeg_data, 'black')
plt.xlabel=('time')
plt.ylabel=('mV')
plt.show()

# %%
for i in range(0, len(np_eeg_data) // eeg_width):
    eeg_width_data = np_eeg_data[(i * eeg_width) : (i+1) * eeg_width]
    print(eeg_data)
# Out:
# [ 1.000e+02  1.240e+02  1.530e+02  1.850e+02  2.100e+02  2.200e+02
#   2.160e+02  2.220e+02  2.400e+02  2.650e+02  2.980e+02  3.300e+02
#   3.620e+02  3.810e+02  3.910e+02  3.900e+02  3.900e+02  3.920e+02
#   3.950e+02  3.970e+02  3.970e+02  3.930e+02  3.800e+02  3.560e+02
#   3.340e+02  3.220e+02  3.200e+02  3.220e+02  3.380e+02  3.320e+02
#   3.170e+02  2.630e+02  1.950e+02  1.420e+02  1.080e+02  9.700e+01
#   8.000e+01  8.000e+01  8.500e+01  3.900e+01 -1.390e+02 -8.160e+02
#  -1.202e+03 -1.374e+03 -1.074e+03 -5.570e+02 -1.930e+02  5.100e+01
#   5.100e+01  2.720e+02  3.950e+02  4.070e+02  3.360e+02  2.090e+02
#   5.400e+01 -1.300e+01 -7.000e+00  4.800e+01  1.180e+02  2.330e+02
#   4.040e+02  5.780e+02  6.490e+02  6.270e+02  5.990e+02  5.770e+02
#   5.550e+02  4.830e+02  3.690e+02  2.240e+02  2.000e+00 -3.090e+02
#  -6.180e+02 -8.090e+02 -7.750e+02 -4.700e+02 -5.900e+01  3.430e+02
#   5.700e+02  6.000e+02  3.970e+02  5.800e+01 -4.560e+02 -7.180e+02
# ...
